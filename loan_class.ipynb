# %% [markdown]
# <a href="https://www.bigdatauniversity.com"><img src="https://ibm.box.com/shared/static/cw2c7r3o20w9zn8gkecaeyjhgw3xdgbj.png" width="400" align="center"></a>
#
# <h1 align="center"><font size="5">Classification with Python</font></h1>

# %% [markdown]
# In this notebook we try to practice all the classification algorithms that we learned in this course.
#
# We load a dataset using Pandas library, and apply the following algorithms, and find the best one for this specific dataset by accuracy evaluation methods.
#
# Lets first load required libraries:

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import pandas as pd
import numpy as np
import matplotlib.ticker as ticker
from sklearn import preprocessing
# %matplotlib inline

# %% [markdown]
# ### About dataset

# %% [markdown]
# This dataset is about past loans. The __Loan_train.csv__ data set includes details of 346 customers whose loan are already paid off or defaulted. It includes following fields:
#
# | Field          | Description                                                                           |
# |----------------|---------------------------------------------------------------------------------------|
# | Loan_status    | Whether a loan is paid off on in collection                                           |
# | Principal      | Basic principal loan amount at the                                                    |
# | Terms          | Origination terms which can be weekly (7 days), biweekly, and monthly payoff schedule |
# | Effective_date | When the loan got originated and took effects                                         |
# | Due_date       | Since it’s one-time payoff schedule, each loan has one single due date                |
# | Age            | Age of applicant                                                                      |
# | Education      | Education of applicant                                                                |
# | Gender         | The gender of applicant                                                               |

# %% [markdown]
# Lets download the dataset

# %%
# !wget -O loan_train.csv https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/loan_train.csv
# Out:
# --2019-03-24 14:33:03--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/loan_train.csv
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.193
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.193|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23101 (23K) [text/csv]
# Saving to: ‘loan_train.csv’
#
# 100%[======================================>] 23,101      --.-K/s   in 0.002s
#
# 2019-03-24 14:33:03 (12.7 MB/s) - ‘loan_train.csv’ saved [23101/23101]

# %% [markdown]
# ### Load Data From CSV File

# %%
df = pd.read_csv('loan_train.csv')
df.size
# Out:
# 3460

# %%
df.shape
# Out:
# (346, 10)

# %% [markdown]
# ### Convert to date time object

# %%
df['due_date'] = pd.to_datetime(df['due_date'])
df['effective_date'] = pd.to_datetime(df['effective_date'])
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30     2016-09-08
# 1           2             2     PAIDOFF       1000     30     2016-09-08
# 2           3             3     PAIDOFF       1000     15     2016-09-08
# 3           4             4     PAIDOFF       1000     30     2016-09-09
# 4           6             6     PAIDOFF       1000     30     2016-09-09
#
#     due_date  age             education  Gender
# 0 2016-10-07   45  High School or Below    male
# 1 2016-10-07   33              Bechalor  female
# 2 2016-09-22   27               college    male
# 3 2016-10-08   28               college  female
# 4 2016-10-08   29               college    male

# %% [markdown]
# # Data visualization and pre-processing

# %% [markdown]
# Let’s see how many of each class is in our data set

# %%
df['loan_status'].value_counts()
# Out:
# PAIDOFF       260
# COLLECTION     86
# Name: loan_status, dtype: int64

# %% [markdown]
# 260 people have paid off the loan on time while 86 have gone into collection

# %% [markdown]
# Lets plot some columns to underestand data better:

# %%
# notice: installing seaborn might takes a few minutes
# !conda install -c anaconda seaborn -y
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following packages will be UPDATED:
#
#     seaborn: 0.8.0-py35h15a2772_0 --> 0.9.0-py35_0 anaconda
#
# seaborn-0.9.0- 100% |################################| Time: 0:00:00  48.54 MB/s

# %%
import seaborn as sns

bins = np.linspace(df.Principal.min(), df.Principal.max(), 10)
g = sns.FacetGrid(df, col="Gender", hue="loan_status", palette="Set1", col_wrap=2)
g.map(plt.hist, 'Principal', bins=bins, ec="k")

g.axes[-1].legend()
plt.show()

# %%
bins = np.linspace(df.age.min(), df.age.max(), 10)
g = sns.FacetGrid(df, col="Gender", hue="loan_status", palette="Set1", col_wrap=2)
g.map(plt.hist, 'age', bins=bins, ec="k")

g.axes[-1].legend()
plt.show()

# %% [markdown]
# # Pre-processing:  Feature selection/extraction

# %% [markdown]
# ### Lets look at the day of the week people get the loan

# %%
df['dayofweek'] = df['effective_date'].dt.dayofweek
bins = np.linspace(df.dayofweek.min(), df.dayofweek.max(), 10)
g = sns.FacetGrid(df, col="Gender", hue="loan_status", palette="Set1", col_wrap=2)
g.map(plt.hist, 'dayofweek', bins=bins, ec="k")
g.axes[-1].legend()
plt.show()

# %% [markdown]
# We see that people who get the loan at the end of the week dont pay it off, so lets use Feature binarization to set a threshold values less then day 4

# %%
df['weekend'] = df['dayofweek'].apply(lambda x: 1 if (x>3)  else 0)
df
# Out:
#      Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0             0             0     PAIDOFF       1000     30     2016-09-08
# 1             2             2     PAIDOFF       1000     30     2016-09-08
# 2             3             3     PAIDOFF       1000     15     2016-09-08
# 3             4             4     PAIDOFF       1000     30     2016-09-09
# 4             6             6     PAIDOFF       1000     30     2016-09-09
# 5             7             7     PAIDOFF       1000     30     2016-09-09
# 6             8             8     PAIDOFF       1000     30     2016-09-09
# 7             9             9     PAIDOFF        800     15     2016-09-10
# 8            10            10     PAIDOFF        300      7     2016-09-10
# 9            11            11     PAIDOFF       1000     15     2016-09-10
# 10           12            12     PAIDOFF       1000     30     2016-09-10
# 11           13            13     PAIDOFF        900      7     2016-09-10
# 12           14            14     PAIDOFF       1000      7     2016-09-10
# 13           15            15     PAIDOFF        800     15     2016-09-10
# 14           16            16     PAIDOFF       1000     30     2016-09-10
# 15           17            17     PAIDOFF       1000     15     2016-09-10
# 16           18            18     PAIDOFF       1000     30     2016-09-10
# 17           19            19     PAIDOFF        800     30     2016-09-10
# 18           20            20     PAIDOFF       1000     30     2016-09-10
# 19           22            22     PAIDOFF       1000     30     2016-09-10
# 20           23            23     PAIDOFF       1000     15     2016-09-10
# 21           25            25     PAIDOFF       1000     30     2016-09-10
# 22           26            26     PAIDOFF        800     15     2016-09-10
# 23           27            27     PAIDOFF       1000     15     2016-09-10
# 24           28            28     PAIDOFF       1000     30     2016-09-11
# 25           29            29     PAIDOFF       1000     30     2016-09-11
# 26           30            30     PAIDOFF        800     15     2016-09-11
# 27           31            31     PAIDOFF       1000     30     2016-09-11
# 28           32            32     PAIDOFF       1000     30     2016-09-11
# 29           33            33     PAIDOFF       1000     30     2016-09-11
# ..          ...           ...         ...        ...    ...            ...
# 316         367           367  COLLECTION        800     15     2016-09-11
# 317         368           368  COLLECTION       1000     30     2016-09-11
# 318         371           371  COLLECTION       1000     30     2016-09-11
# 319         372           372  COLLECTION        800     15     2016-09-11
# 320         373           373  COLLECTION       1000     15     2016-09-11
# 321         374           374  COLLECTION       1000     30     2016-09-11
# 322         375           375  COLLECTION        800     15     2016-09-11
# 323         376           376  COLLECTION       1000     15     2016-09-11
# 324         377           377  COLLECTION       1000     30     2016-09-11
# 325         378           378  COLLECTION       1000     30     2016-09-11
# 326         379           379  COLLECTION       1000     30     2016-09-11
# 327         380           380  COLLECTION       1000     30     2016-09-11
# 328         381           381  COLLECTION        800     15     2016-09-11
# 329         382           382  COLLECTION       1000     15     2016-09-11
# 330         383           383  COLLECTION       1000     30     2016-09-11
# 331         384           384  COLLECTION       1000     30     2016-09-11
# 332         385           385  COLLECTION       1000     30     2016-09-11
# 333         386           386  COLLECTION        800     15     2016-09-11
# 334         387           387  COLLECTION       1000     30     2016-09-11
# 335         388           388  COLLECTION       1000     15     2016-09-11
# 336         389           389  COLLECTION       1000     15     2016-09-11
# 337         390           390  COLLECTION       1000     15     2016-09-11
# 338         391           391  COLLECTION        800     15     2016-09-11
# 339         392           392  COLLECTION       1000     30     2016-09-11
# 340         393           393  COLLECTION       1000     30     2016-09-11
# 341         394           394  COLLECTION        800     15     2016-09-11
# 342         395           395  COLLECTION       1000     30     2016-09-11
# 343         397           397  COLLECTION        800     15     2016-09-12
# 344         398           398  COLLECTION       1000     30     2016-09-12
# 345         399           399  COLLECTION       1000     30     2016-09-12
#
#       due_date  age             education  Gender  dayofweek  weekend
# 0   2016-10-07   45  High School or Below    male          3        0
# 1   2016-10-07   33              Bechalor  female          3        0
# 2   2016-09-22   27               college    male          3        0
# 3   2016-10-08   28               college  female          4        1
# 4   2016-10-08   29               college    male          4        1
# 5   2016-10-08   36               college    male          4        1
# 6   2016-10-08   28               college    male          4        1
# 7   2016-09-24   26               college    male          5        1
# 8   2016-09-16   29               college    male          5        1
# 9   2016-10-09   39  High School or Below    male          5        1
# 10  2016-10-09   26               college    male          5        1
# 11  2016-09-16   26               college  female          5        1
# 12  2016-09-16   27  High School or Below    male          5        1
# 13  2016-09-24   26               college    male          5        1
# 14  2016-10-09   40  High School or Below    male          5        1
# 15  2016-09-24   32  High School or Below    male          5        1
# 16  2016-10-09   32  High School or Below    male          5        1
# 17  2016-10-09   26               college    male          5        1
# 18  2016-10-09   26               college    male          5        1
# 19  2016-10-09   25  High School or Below    male          5        1
# 20  2016-09-24   26               college    male          5        1
# 21  2016-10-09   29  High School or Below    male          5        1
# 22  2016-09-24   39              Bechalor    male          5        1
# 23  2016-09-24   34              Bechalor    male          5        1
# 24  2016-10-10   31               college    male          6        1
# 25  2016-10-10   33               college    male          6        1
# 26  2016-09-25   33  High School or Below    male          6        1
# 27  2016-10-10   37               college    male          6        1
# 28  2016-10-10   27               college    male          6        1
# 29  2016-10-10   37               college    male          6        1
# ..         ...  ...                   ...     ...        ...      ...
# 316 2016-09-25   28              Bechalor    male          6        1
# 317 2016-10-10   24               college    male          6        1
# 318 2016-10-10   18               college    male          6        1
# 319 2016-09-25   25  High School or Below    male          6        1
# 320 2016-09-25   40  High School or Below    male          6        1
# 321 2016-10-10   29               college    male          6        1
# 322 2016-09-25   26  High School or Below  female          6        1
# 323 2016-09-25   30               college    male          6        1
# 324 2016-10-10   33               college    male          6        1
# 325 2016-10-10   30               college    male          6        1
# 326 2016-10-10   32               college    male          6        1
# 327 2016-10-10   25  High School or Below    male          6        1
# 328 2016-09-25   35  High School or Below    male          6        1
# 329 2016-09-25   30              Bechalor    male          6        1
# 330 2016-10-10   26  High School or Below    male          6        1
# 331 2016-10-10   29  High School or Below    male          6        1
# 332 2016-11-09   26  High School or Below    male          6        1
# 333 2016-09-25   46  High School or Below    male          6        1
# 334 2016-10-10   36  High School or Below    male          6        1
# 335 2016-09-25   38              Bechalor    male          6        1
# 336 2016-10-25   32  High School or Below    male          6        1
# 337 2016-09-25   30               college    male          6        1
# 338 2016-09-25   35  High School or Below    male          6        1
# 339 2016-10-10   29               college  female          6        1
# 340 2016-11-09   26               college    male          6        1
# 341 2016-09-25   32  High School or Below    male          6        1
# 342 2016-10-10   25  High School or Below    male          6        1
# 343 2016-09-26   39               college    male          0        0
# 344 2016-11-10   28               college    male          0        0
# 345 2016-10-11   26               college    male          0        0
#
# [346 rows x 12 columns]

# %% [markdown]
# ## Convert Categorical features to numerical values

# %% [markdown]
# Lets look at gender:

# %%
df.groupby(['Gender'])['loan_status'].value_counts(normalize=True)
# Out:
# Gender  loan_status
# female  PAIDOFF        0.865385
#         COLLECTION     0.134615
# male    PAIDOFF        0.731293
#         COLLECTION     0.268707
# Name: loan_status, dtype: float64

# %% [markdown]
# 86 % of female pay there loans while only 73 % of males pay there loan

# %% [markdown]
# Lets convert male to 0 and female to 1:

# %%
df['Gender'].replace(to_replace=['male','female'], value=[0,1],inplace=True)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30     2016-09-08
# 1           2             2     PAIDOFF       1000     30     2016-09-08
# 2           3             3     PAIDOFF       1000     15     2016-09-08
# 3           4             4     PAIDOFF       1000     30     2016-09-09
# 4           6             6     PAIDOFF       1000     30     2016-09-09
#
#     due_date  age             education  Gender  dayofweek  weekend
# 0 2016-10-07   45  High School or Below       0          3        0
# 1 2016-10-07   33              Bechalor       1          3        0
# 2 2016-09-22   27               college       0          3        0
# 3 2016-10-08   28               college       1          4        1
# 4 2016-10-08   29               college       0          4        1

# %% [markdown]
# ## One Hot Encoding
# #### How about education?

# %%
df.groupby(['education'])['loan_status'].value_counts(normalize=True)
# Out:
# education             loan_status
# Bechalor              PAIDOFF        0.750000
#                       COLLECTION     0.250000
# High School or Below  PAIDOFF        0.741722
#                       COLLECTION     0.258278
# Master or Above       COLLECTION     0.500000
#                       PAIDOFF        0.500000
# college               PAIDOFF        0.765101
#                       COLLECTION     0.234899
# Name: loan_status, dtype: float64

# %% [markdown]
# #### Feature befor One Hot Encoding

# %%
df[['Principal','terms','age','Gender','education']].head()
# Out:
#    Principal  terms  age  Gender             education
# 0       1000     30   45       0  High School or Below
# 1       1000     30   33       1              Bechalor
# 2       1000     15   27       0               college
# 3       1000     30   28       1               college
# 4       1000     30   29       0               college

# %% [markdown]
# #### Use one hot encoding technique to conver categorical varables to binary variables and append them to the feature Data Frame

# %%
Feature = df[['Principal','terms','age','Gender','weekend']]
Feature = pd.concat([Feature,pd.get_dummies(df['education'])], axis=1)
Feature.drop(['Master or Above'], axis = 1,inplace=True)
Feature.head()
# Out:
#    Principal  terms  age  Gender  weekend  Bechalor  High School or Below  \
# 0       1000     30   45       0        0         0                     1
# 1       1000     30   33       1        0         1                     0
# 2       1000     15   27       0        0         0                     0
# 3       1000     30   28       1        1         0                     0
# 4       1000     30   29       0        1         0                     0
#
#    college
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1

# %% [markdown]
# ### Feature selection

# %% [markdown]
# Lets defind feature sets, X:

# %%
X = Feature

# %% [markdown]
# What are our lables?

# %%
y = df['loan_status'].values
y[0:5]
# Out:
# array(['PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF'], dtype=object)

# %% [markdown]
# ## Normalize Data

# %% [markdown]
# Data Standardization give data zero mean and unit variance (technically should be done after train test split )

# %%
X= preprocessing.StandardScaler().fit(X).transform(X)
X
# Out:
# array([[ 0.51578458,  0.92071769,  2.33152555, ..., -0.38170062,
#          1.13639374, -0.86968108],
#        [ 0.51578458,  0.92071769,  0.34170148, ...,  2.61985426,
#         -0.87997669, -0.86968108],
#        [ 0.51578458, -0.95911111, -0.65321055, ..., -0.38170062,
#         -0.87997669,  1.14984679],
#        ...,
#        [-1.31458942, -0.95911111,  1.33661351, ..., -0.38170062,
#         -0.87997669,  1.14984679],
#        [ 0.51578458,  0.92071769, -0.48739188, ..., -0.38170062,
#         -0.87997669,  1.14984679],
#        [ 0.51578458,  0.92071769, -0.81902922, ..., -0.38170062,
#         -0.87997669,  1.14984679]])

# %% [markdown]
# # Classification

# %% [markdown]
# Now, it is your turn, use the training set to build an accurate model. Then use the test set to report the accuracy of the model
# You should use the following algorithm:
# - K Nearest Neighbor(KNN)
# - Decision Tree
# - Support Vector Machine
# - Logistic Regression
#
#
#
# __ Notice:__
# - You can go above and change the pre-processing, feature selection, feature-extraction, and so on, to make a better model.
# - You should use either scikit-learn, Scipy or Numpy libraries for developing the classification algorithms.
# - You should include the code of the algorithm in the following cells.

# %% [markdown]
# # K Nearest Neighbor(KNN)
# Notice: You should find the best k to build the model with the best accuracy.
# **warning:** You should not use the __loan_test.csv__ for finding the best k, however, you can split your train_loan.csv into train and test to find the best __k__.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.3, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (242, 8) (242,)
# Test set: (104, 8) (104,)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
k = 9

neigh = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
k_yhat = neigh.predict(X_test)


print("Train set Accuracy: ", metrics.accuracy_score(y_train, neigh.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, k_yhat))
# Out:
# Train set Accuracy:  0.793388429752
# Test set Accuracy:  0.75

# %%
Ks = 10
mean_acc = np.zeros((Ks-1))
std_acc = np.zeros((Ks-1))
ConfustionMx = [];
for n in range(1,Ks):
    
    #Train Model and Predict  
    neigh = KNeighborsClassifier(n_neighbors = n).fit(X_train,y_train)
    yhat=neigh.predict(X_test)
    mean_acc[n-1] = metrics.accuracy_score(y_test, yhat)

    
    std_acc[n-1]=np.std(yhat==y_test)/np.sqrt(yhat.shape[0])

mean_acc
print( "The best accuracy was with", mean_acc.max(), "with k=", mean_acc.argmax()+1)
# Out:
# The best accuracy was with 0.75 with k= 9

# %%
plt.plot(range(1,Ks),mean_acc,'g')
plt.fill_between(range(1,Ks),mean_acc - 1 * std_acc,mean_acc + 1 * std_acc, alpha=0.10)
plt.legend(('Accuracy ', '+/- 3xstd'))
plt.ylabel('Accuracy ')
plt.xlabel('Number of Nabors (K)')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
loanTree = DecisionTreeClassifier(criterion="entropy", splitter='best', max_depth = 2)
loanTree.fit(X_train,y_train)
predTree = loanTree.predict(X_test)

# %%
print("DecisionTree Accuracy= ", metrics.accuracy_score(y_test, predTree))
# Out:
# DecisionTree Accuracy=  0.740384615385

# %%
# !conda install -c conda-forge pydotplus -y
# !conda install -c conda-forge python-graphviz -y
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     pydotplus: 2.0.2-py_2 conda-forge
#
# pydotplus-2.0. 100% |################################| Time: 0:00:00  16.10 MB/s
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     python-graphviz: 0.10.1-py_0 conda-forge
#
# python-graphvi 100% |################################| Time: 0:00:00  15.58 MB/s

# %%
from sklearn.externals.six import StringIO
import pydotplus
import matplotlib.image as mpimg
from sklearn import tree
# %matplotlib inline

# %%
dot_data = StringIO()
filename = "loantree.png"
featureNames = Feature.columns
targetNames = df["loan_status"].unique().tolist()
out=tree.export_graphviz(loanTree,feature_names=featureNames, out_file=dot_data, class_names= np.unique(y_train), filled=True,  special_characters=True,rotate=False)  
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png(filename)
img = mpimg.imread(filename)
plt.figure(figsize=(20, 40))
plt.imshow(img,interpolation='nearest')

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn import svm
loan_svm = svm.SVC(kernel='rbf', gamma=9)
loan_svm.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=9, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
SVMyhat = loan_svm.predict(X_test)
SVMyhat [0:5]
# Out:
# array(['PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF'], dtype=object)

# %%
from sklearn.metrics import classification_report, confusion_matrix
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
cnf_matrix = confusion_matrix(y_test, yhat, labels=['PAIDOFF','COLLECTION'])
np.set_printoptions(precision=2)

print (classification_report(y_test, yhat))

plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['PAIDOFF','COLLECTION'],normalize= False,  title='Confusion matrix')
# Out:
#              precision    recall  f1-score   support
#
#  COLLECTION       0.53      0.33      0.41        27
#     PAIDOFF       0.79      0.90      0.84        77
#
# avg / total       0.72      0.75      0.73       104
#
# Confusion matrix, without normalization
# [[69  8]
#  [18  9]]

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
LoanLR = LogisticRegression(C=0.1, solver='liblinear').fit(X_train,y_train)
LoanLR
# Out:
# LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
LRyhat = LoanLR.predict(X_test)

# %%
from sklearn.metrics import jaccard_similarity_score
jaccard_similarity_score(y_test, LRyhat)
# Out:
# 0.73076923076923073

# %% [markdown]
# # Model Evaluation using Test set

# %%
from sklearn.metrics import jaccard_similarity_score
from sklearn.metrics import f1_score
from sklearn.metrics import log_loss

# %% [markdown]
# First, download and load the test set:

# %%
# !wget -O loan_test.csv https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/loan_test.csv
# Out:
# --2019-03-24 14:36:05--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/loan_test.csv
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.193
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.193|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3642 (3.6K) [text/csv]
# Saving to: ‘loan_test.csv’
#
# 100%[======================================>] 3,642       --.-K/s   in 0s
#
# 2019-03-24 14:36:05 (766 MB/s) - ‘loan_test.csv’ saved [3642/3642]

# %% [markdown]
# ### Load Test set for evaluation

# %%
test_df = pd.read_csv('loan_test.csv')
test_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           1             1     PAIDOFF       1000     30       9/8/2016
# 1           5             5     PAIDOFF        300      7       9/9/2016
# 2          21            21     PAIDOFF       1000     30      9/10/2016
# 3          24            24     PAIDOFF       1000     30      9/10/2016
# 4          35            35     PAIDOFF        800     15      9/11/2016
#
#     due_date  age             education  Gender
# 0  10/7/2016   50              Bechalor  female
# 1  9/15/2016   35       Master or Above    male
# 2  10/9/2016   43  High School or Below  female
# 3  10/9/2016   26               college    male
# 4  9/25/2016   29              Bechalor    male

# %%
test_df['due_date'] = pd.to_datetime(test_df['due_date'])
test_df['effective_date'] = pd.to_datetime(test_df['effective_date'])
test_df['dayofweek'] = test_df['effective_date'].dt.dayofweek
test_df['weekend'] = test_df['dayofweek'].apply(lambda x: 1 if (x>3)  else 0)
test_df.groupby(['Gender'])['loan_status'].value_counts(normalize=True)
test_df['Gender'].replace(to_replace=['male','female'], value=[0,1],inplace=True)
test_df.groupby(['education'])['loan_status'].value_counts(normalize=True)


Feature_Test = test_df[['Principal','terms','age','Gender','weekend']]
Feature_Test = pd.concat([Feature_Test,pd.get_dummies(test_df['education'])], axis=1)
Feature_Test.drop(['Master or Above'], axis = 1,inplace=True)

XT = Feature_Test
XT= preprocessing.StandardScaler().fit(XT).transform(XT)
yT = test_df['loan_status'].values

# %%
''''f1_score(yT, yhat,average = 'macro')
from Sklearn Doc: average='micro'==> Calculate metrics for each label, 
and find their average weighted by support (the number of true instances for each label). 
This alters ‘macro’ to account for label imbalance; it can result in an F-score that is not between precision and recall.'''

k_yhat = neigh.predict(XT)
k_jac=jaccard_similarity_score(yT, k_yhat)
Kyhat_F1=f1_score(yT, k_yhat,average='weighted')
#
predTree = loanTree.predict(XT)
Tree_jac=jaccard_similarity_score(yT, predTree)
Tree_F1=f1_score(yT, predTree, average='weighted')
#
SVMyhat = loan_svm.predict(XT)
SVM_jac=jaccard_similarity_score(yT, SVMyhat)
SVM_F1=f1_score(yT, SVMyhat, average='weighted') 
#
LRyhat = LoanLR.predict(XT)
logreg_jac=jaccard_similarity_score(yT, LRyhat)
logreg_F1=f1_score(yT, LRyhat, average='weighted')
LRyhat_prob = LoanLR.predict_proba(XT)
logreg_logloss=log_loss(yT, LRyhat_prob)
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
eval_data = {'Algorithm': 
             ['KNN','Decision Tree','SVM', 'Logistic Regression'],
             'Jaccard': [k_jac,Tree_jac,SVM_jac, logreg_jac],
             'F1-Score': [Kyhat_F1,Tree_F1,SVM_F1,logreg_F1],
             'LogLoss':['NA','NA','NA',logreg_logloss]}
eval_df = pd.DataFrame(data=eval_data)
blankIndex=[''] * len(eval_df)
eval_df.index=blankIndex
eval_df
# Out:
#             Algorithm  F1-Score   Jaccard   LogLoss
#                   KNN  0.615152  0.666667        NA
#         Decision Tree  0.630418  0.740741        NA
#                   SVM  0.611916  0.703704        NA
#   Logistic Regression  0.671764  0.759259  0.482491

# %% [markdown]
# # Report
# You should be able to report the accuracy of the built model using different evaluation metrics:

# %% [markdown]
# | Algorithm          | Jaccard | F1-score | LogLoss |
# |--------------------|---------|----------|---------|
# | KNN                | ?       | ?        | NA      |
# | Decision Tree      | ?       | ?        | NA      |
# | SVM                | ?       | ?        | NA      |
# | LogisticRegression | ?       | ?        | ?       |

# %% [markdown]
# <h2>Want to learn more?</h2>
#
# IBM SPSS Modeler is a comprehensive analytics platform that has many machine learning algorithms. It has been designed to bring predictive intelligence to decisions made by individuals, by groups, by systems – by your enterprise as a whole. A free trial is available through this course, available here: <a href="http://cocl.us/ML0101EN-SPSSModeler">SPSS Modeler</a>
#
# Also, you can use Watson Studio to run these notebooks faster with bigger datasets. Watson Studio is IBM's leading cloud solution for data scientists, built by data scientists. With Jupyter notebooks, RStudio, Apache Spark and popular libraries pre-packaged in the cloud, Watson Studio enables data scientists to collaborate on their projects without having to install anything. Join the fast-growing community of Watson Studio users today with a free account at <a href="https://cocl.us/ML0101EN_DSX">Watson Studio</a>
#
# <h3>Thanks for completing this lesson!</h3>
#
# <h4>Author:  <a href="https://ca.linkedin.com/in/saeedaghabozorgi">Saeed Aghabozorgi</a></h4>
# <p><a href="https://ca.linkedin.com/in/saeedaghabozorgi">Saeed Aghabozorgi</a>, PhD is a Data Scientist in IBM with a track record of developing enterprise level applications that substantially increases clients’ ability to turn data into actionable knowledge. He is a researcher in data mining field and expert in developing advanced analytic methods like machine learning and statistical modelling on large datasets.</p>
#
# <hr>
#
# <p>Copyright &copy; 2018 <a href="https://cocl.us/DX0108EN_CC">Cognitive Class</a>. This notebook and its source code are released under the terms of the <a href="https://bigdatauniversity.com/mit-license/">MIT License</a>.</p>
